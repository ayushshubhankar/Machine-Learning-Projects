# %%
# importing the Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Getting the Data
df= pd.read_csv(r"C:\Users\ayush\Desktop\Machine Learning Projects\Parkinson's Disease\parkinsons.data")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## EDA
# * We would be exploring the Data in General

# %%
# Top 5 rows of the Data
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
# Bottom 5 rows of the Data
df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
# General Information about The Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
# Gathering some useful statistical Values
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %% [markdown]
# ### The Data has two types of Status:-
# * Status=1 --- The person has Parkinson's Disease.
# * Status=0 --- The person does not have Parkinson's Disease.

# %%
# Finding if The Data has some Missing Values.
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
sns.countplot(x="status",data=df,hue="status")
plt.xlabel("Status")
plt.ylabel("Count")
plt.title("Count of Persons with or without Disease", weight="bold", size= 15)
# Out:
# Text(0.5, 1.0, 'Count of Persons with or without Disease')

# %% [markdown]
# # Machine Learning

# %%
#Splitting the Data into X and Y. 
# X would contain all the cloumns except Name and Status.
x=df.drop(columns=['name','status'],axis=1)
# Y would only contain the Loan Status.
y=df["status"]

# %%
x
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %% [markdown]
# * We would be following the steps as per the pathway at https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
# * Since this is a classification problem, we would be following the classification pathway

# %%
# Splitting the DATA into Training and Test with a test size of 20%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.2)

# %%
x_train
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 67       136.969       166.607        66.004         0.00923
# 102      139.224       586.567        66.157         0.03011
# 119      217.116       233.481        93.978         0.00404
# 155      117.870       127.349        95.654         0.00647
# 93       152.125       161.469        76.596         0.00382
# ..           ...           ...           ...             ...
# 192      174.688       240.005        74.287         0.01360
# 60       209.144       237.494       109.379         0.00282
# 13       139.173       179.139        76.556         0.00390
# 49       122.964       130.049       114.676         0.00428
# 169      240.301       245.135       219.783         0.00517
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 67            0.00007   0.00507   0.00463     0.01520       0.03111
# 102           0.00022   0.01854   0.01628     0.05563       0.09419
# ...

# %%
x_test
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 58       116.879       131.897       108.153         0.00788
# 189      201.774       262.707        78.228         0.00694
# 55       109.860       126.358       104.437         0.00874
# 77       110.568       125.394       106.821         0.00462
# 78        95.385       102.145        90.264         0.00608
# 18       153.046       175.829        68.623         0.00742
# 183      117.226       123.925       106.656         0.00417
# 9         95.056       120.103        91.226         0.00532
# 10        88.333       112.240        84.072         0.00505
# 45       242.852       255.034       227.911         0.00225
# 164      102.273       142.830        85.902         0.00907
# 82       100.960       110.019        95.628         0.00606
# 105      149.689       160.368       133.608         0.00257
# 75       110.707       122.611       105.007         0.00516
# ...

# %%
y_train
# Out:
# 67     1
# 102    1
# 119    1
# 155    1
# 93     1
#       ..
# 192    0
# 60     0
# 13     1
# 49     0
# 169    0
# Name: status, Length: 156, dtype: int64

# %%
y_test
# Out:
# 58     1
# 189    0
# 55     1
# 77     1
# 78     1
# 18     1
# 183    0
# 9      1
# 10     1
# 45     0
# 164    1
# 82     1
# 105    1
# 75     1
# 129    1
# 124    1
# 99     1
# 120    1
# 118    1
# 28     1
# 94     1
# 39     1
# 160    1
# 27     1
# 89     1
# 180    1
# 41     1
# 31     0
# 163    1
# 185    0
# 90     1
# 26     1
# 70     1
# 1      1
# 166    0
# 11     1
# 115    1
# 46     0
# 161    1
# Name: status, dtype: int64

# %%
# Scaling the data by using Standard Scaler
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train= sc.fit_transform(x_train)
x_test= sc.transform(x_test)

# %% [markdown]
# ### Linear SVC

# %%
# Importing the Linear SVC from the Scikit Learn Library.
from sklearn.svm import LinearSVC
lc=LinearSVC()
lc.fit(x_train,y_train)
y_pred_lc= lc.predict(x_test)
y_test
# Out:
# 58     1
# 189    0
# 55     1
# 77     1
# 78     1
# 18     1
# 183    0
# 9      1
# 10     1
# 45     0
# 164    1
# 82     1
# 105    1
# 75     1
# 129    1
# 124    1
# 99     1
# 120    1
# 118    1
# 28     1
# 94     1
# 39     1
# 160    1
# 27     1
# 89     1
# 180    1
# 41     1
# 31     0
# 163    1
# 185    0
# 90     1
# 26     1
# 70     1
# 1      1
# 166    0
# 11     1
# 115    1
# 46     0
# 161    1
# Name: status, dtype: int64

# %%
from sklearn.metrics import accuracy_score
lc_score= round((accuracy_score(y_pred_lc,y_test))*100)
print("The Accuracy score for Linear SVC is ", lc_score, "%")
# Out:
# The Accuracy score for Linear SVC is  87 %

# %% [markdown]
# ### KNN Method

# %%
# Importing thr Libraries
from sklearn.neighbors import KNeighborsClassifier
# Gathering the optiumum number of Neighbors
for i in range(1,15):
    kn=KNeighborsClassifier(n_neighbors=i)
    kn.fit(x_train,y_train)
    y_pred_kn= kn.predict(x_test)
    kn_score=round((accuracy_score(y_pred_kn,y_test)*100))
    print(i, "-----", kn_score,"%")
    i=i+1
# Out:
# 1 ----- 95 %
# 2 ----- 92 %
# 3 ----- 95 %
# 4 ----- 92 %
# 5 ----- 90 %
# 6 ----- 85 %
# 7 ----- 90 %
# 8 ----- 87 %
# 9 ----- 90 %
# 10 ----- 90 %
# 11 ----- 92 %
# 12 ----- 87 %
# 13 ----- 90 %
# 14 ----- 90 %

# %%
# Predicting the scores using the Optimim Neighbors.
kn=KNeighborsClassifier(n_neighbors=6)
kn.fit(x_train,y_train)
y_pred_kn= kn.predict(x_test)
kn_score=round((accuracy_score(y_pred_kn,y_test)*100))
print("The Accuracy score for KNN is ", kn_score, "%")
# Out:
# The Accuracy score for KNN is  85 %

# %% [markdown]
# ### Random Forest

# %%
# Importing the Libraries.
from sklearn.ensemble import RandomForestClassifier
# Gathering the optiumum number of estimators
for i in range(1,150):
    rf=RandomForestClassifier(n_estimators=i)
    rf.fit(x_train,y_train)
    y_pred_rf= rf.predict(x_test)
    rf_score=round((accuracy_score(y_pred_rf,y_test)*100))
    print(i, "-----", rf_score,"%")
    i=i+1
# Out:
# 1 ----- 85 %
# 2 ----- 87 %
# 3 ----- 85 %
# 4 ----- 90 %
# 5 ----- 90 %
# 6 ----- 87 %
# 7 ----- 92 %
# 8 ----- 87 %
# 9 ----- 87 %
# 10 ----- 85 %
# 11 ----- 90 %
# 12 ----- 90 %
# 13 ----- 90 %
# 14 ----- 90 %
# 15 ----- 90 %
# 16 ----- 87 %
# 17 ----- 90 %
# 18 ----- 90 %
# 19 ----- 90 %
# 20 ----- 90 %
# 21 ----- 90 %
# 22 ----- 92 %
# 23 ----- 90 %
# 24 ----- 87 %
# 25 ----- 92 %
# 26 ----- 90 %
# 27 ----- 90 %
# 28 ----- 92 %
# 29 ----- 90 %
# 30 ----- 90 %
# 31 ----- 92 %
# 32 ----- 90 %
# 33 ----- 90 %
# 34 ----- 90 %
# 35 ----- 87 %
# 36 ----- 92 %
# 37 ----- 92 %
# 38 ----- 87 %
# 39 ----- 87 %
# 40 ----- 92 %
# 41 ----- 90 %
# 42 ----- 87 %
# 43 ----- 90 %
# 44 ----- 90 %
# 45 ----- 90 %
# 46 ----- 90 %
# 47 ----- 90 %
# 48 ----- 90 %
# 49 ----- 90 %
# 50 ----- 90 %
# 51 ----- 92 %
# 52 ----- 87 %
# 53 ----- 90 %
# 54 ----- 90 %
# 55 ----- 90 %
# 56 ----- 90 %
# 57 ----- 90 %
# 58 ----- 92 %
# 59 ----- 90 %
# 60 ----- 90 %
# 61 ----- 90 %
# 62 ----- 90 %
# 63 ----- 92 %
# ...

# %%
# Predicting the scores using the Optimim Estimators.
rf= RandomForestClassifier(n_estimators=63)
rf.fit(x_train,y_train)
y_pred_rf= rf.predict(x_test)
rf_score=round((accuracy_score(y_pred_rf,y_test)*100))
print("The Accuracy score for RandomForest is ", rf_score, "%")
# Out:
# The Accuracy score for RandomForest is  92 %

# %%
# Concatenating the Scores of Various Models.
scores= {"Model":["Linear SVC","KNN Method","RandomForrest"], "Scores":[lc_score,kn_score,rf_score]}
scores= pd.DataFrame.from_dict(scores)
scores
# Out:
#            Model  Scores
# 0     Linear SVC      87
# 1     KNN Method      85
# 2  RandomForrest      92

# %%
# Plotting the Data for Visualisation
sns.barplot(x="Model",y="Scores",data= scores)
plt.title("Scores Comparison",weight="bold",size=15)
# Out:
# Text(0.5, 1.0, 'Scores Comparison')
